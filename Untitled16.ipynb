# %%
name = "Athulya"
age = 22
print("Hello,", name, "you are", age, "years old.")
# Out:
# Hello, Athulya you are 22 years old.

# %%
def add(a, b):
    return a + b

print(add(10, 5))
# Out:
# 15

# %%
income = 50000
if income > 40000:
    print("Above average income")
else:
    print("Below average income")
# Out:
# Above average income

# %%
num = 7
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd
